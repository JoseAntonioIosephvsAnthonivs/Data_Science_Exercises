# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
lol = pd.read_json('champ_stats.json')
lol.head()
# Out:
#             Aatrox   Ahri  Akali  Alistar  Amumu  Anivia  Annie  Aphelios  \
# hp           580.0  526.0  575.0    600.0  615.0   480.0  524.0     530.0
# hpperlevel    90.0   92.0   95.0    106.0   80.0    82.0   88.0      88.0
# mp             0.0  418.0  200.0    350.0  285.0   495.0  418.0     348.0
# mpperlevel     0.0   25.0    0.0     40.0   40.0    45.0   25.0      42.0
# movespeed    345.0  330.0  345.0    330.0  335.0   325.0  335.0     325.0
#
#              Ashe  AurelionSol  ...  Yasuo   Yone  Yorick  Yuumi    Zac  \
# hp          570.0        575.0  ...  490.0  550.0   580.0  480.0  615.0
# hpperlevel   87.0         92.0  ...   87.0   85.0   100.0   70.0   95.0
# mp          280.0        350.0  ...  100.0  500.0   300.0  400.0    0.0
# mpperlevel   32.0         50.0  ...    0.0    0.0    60.0   45.0    0.0
# movespeed   325.0        325.0  ...  345.0  345.0   340.0  330.0  340.0
#
#               Zed  Ziggs  Zilean    Zoe   Zyra
# ...

# %%
print(lol['Cassiopeia'].dtype)
# Out:
# float64

# %%
lol.describe()
# Out:
#            Aatrox        Ahri       Akali     Alistar       Amumu      Anivia  \
# count   20.000000   20.000000   20.000000   20.000000   20.000000   20.000000
# mean    66.837550  103.474400   76.638750   85.950000   81.250150  107.722550
# std    147.064799  186.663275  146.039177  158.795135  156.981448  194.913033
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.767000    0.593750    1.150000    1.150000    0.756250
# 50%      2.750000    6.750000    5.750000    8.500000    8.191000    6.750000
# 75%     43.500000   62.780000   70.550000   73.000000   60.035000   59.032000
# max    580.000000  550.000000  575.000000  600.000000  615.000000  600.000000
#
#             Annie    Aphelios        Ashe  AurelionSol  ...       Yasuo  \
# count   20.000000   20.000000   20.000000    20.000000  ...   20.000000
# mean   106.927200  100.667000  101.563500   103.584250  ...   66.922350
# ...

# %%
lol.std()
# Out:
# Aatrox     147.064799
# Ahri       186.663275
# Akali      146.039177
# Alistar    158.795135
# Amumu      156.981448
#               ...
# Zed        147.541003
# Ziggs      193.415636
# Zilean     187.035501
# Zoe        191.949359
# Zyra       187.765932
# Length: 153, dtype: float64

# %%
Cassiopeia = lol['Cassiopeia'].mean()
print('Casssiopeia median stats: ',Cassiopeia)

Ahri = lol['Ahri'].mean()
print('Ahri median stats: ',Ahri)
# Out:
# Casssiopeia median stats:  103.24735000000001
# Ahri median stats:  103.47440000000002
